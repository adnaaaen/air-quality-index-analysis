# %% [markdown]
# *Made By [Adnan](https://linktr.ee/adnaaaen)*

# %% [markdown]
# # ***Data Preprocessing***

# %%
import pandas as pd
from category_encoders import BinaryEncoder
from sklearn.preprocessing import StandardScaler
import joblib

from warnings import filterwarnings
import os

filterwarnings("ignore")

# %%
if not os.path.exists("../data/cleaned/cleaned.csv"):
    raise Exception("your need to download dataset, visit data/ folder in the root")
    
df = pd.read_csv("../data/cleaned/cleaned.csv", parse_dates=["datetime"])
df.head()
# Out:
#         city            datetime     pm2.5      pm10        no       no2  \
# 0  Ahmedabad 2015-01-29 09:00:00  4.400235  4.532815  0.883768  3.131137
# 1  Ahmedabad 2015-01-29 10:00:00  4.486387  4.532815  1.108563  3.038313
# 2  Ahmedabad 2015-01-29 11:00:00  4.516667  4.532815  1.000632  3.049747
# 3  Ahmedabad 2015-01-29 12:00:00  4.437107  4.532815  0.559616  2.853593
# 4  Ahmedabad 2015-01-29 13:00:00  4.239887  4.532815  0.457425  2.689886
#
#        n_ox       nh3        co       so2        o3  benzene  toluene  \
# 0  3.075005  2.824944  0.883768  3.504355  3.865141      0.0      0.0
# 1  3.145014  2.824944  1.108563  4.381401  3.130263      0.0      0.0
# 2  3.140698  2.824944  1.000632  4.573267  4.229312      0.0      0.0
# 3  2.861057  2.824944  0.559616  3.826683  4.498920      0.0      0.0
# 4  2.602690  2.824944  0.457425  3.571503  4.768564      0.0      0.0
#
#         aqi
# 0  5.666427
# 1  5.204007
# 2  5.209486
# 3  5.209486
# 4  5.192957

# %% [markdown]
# ### ***Feature Engineering***

# %% [markdown]
# **split datetime variable into `day` `month` `year` `hour` `minute`**

# %%
"""extract from exisitng feature"""
df["day"] = df["datetime"].dt.day
df["month"] = df["datetime"].dt.month
df["year"] = df["datetime"].dt.year
df["day_of_week"] = df["datetime"].dt.weekday
df["hour"] = df["datetime"].dt.hour

# %%
""" new feature
5: sat
6: sun
if the day is 5 or 6 : that is a weekend
"""
df["is_weekend"] = df["day_of_week"].isin([5,6]).astype(int)

# %%
""" new feature

- Winter (December - February) : 0
- Summer (March - May)         : 1
- Monsoon (June - September)   : 2
- Autumn (October - November)  : 3
"""

def set_season(month: int):
    if month in [12, 1, 2]:
        return 0  # Winter
    elif month in [3, 4, 5]:
        return 1  # Summer
    elif month in [6, 7, 8, 9]:
        return 2  # Monsoon
    elif month in [10, 11]:
        return 3  # Autumn

df["season"] = df["month"].apply(set_season)

# %%
df = df.drop(["datetime"], axis=1)

# %%
df.head()
# Out:
#         city     pm2.5      pm10        no       no2      n_ox       nh3  \
# 0  Ahmedabad  4.400235  4.532815  0.883768  3.131137  3.075005  2.824944
# 1  Ahmedabad  4.486387  4.532815  1.108563  3.038313  3.145014  2.824944
# 2  Ahmedabad  4.516667  4.532815  1.000632  3.049747  3.140698  2.824944
# 3  Ahmedabad  4.437107  4.532815  0.559616  2.853593  2.861057  2.824944
# 4  Ahmedabad  4.239887  4.532815  0.457425  2.689886  2.602690  2.824944
#
#          co       so2        o3  benzene  toluene       aqi  day  month  year  \
# 0  0.883768  3.504355  3.865141      0.0      0.0  5.666427   29      1  2015
# 1  1.108563  4.381401  3.130263      0.0      0.0  5.204007   29      1  2015
# 2  1.000632  4.573267  4.229312      0.0      0.0  5.209486   29      1  2015
# 3  0.559616  3.826683  4.498920      0.0      0.0  5.209486   29      1  2015
# 4  0.457425  3.571503  4.768564      0.0      0.0  5.192957   29      1  2015
#
#    day_of_week  hour  is_weekend  season
# 0            3     9           0       0
# 1            3    10           0       0
# 2            3    11           0       0
# 3            3    12           0       0
# 4            3    13           0       0

# %% [markdown]
# ### ***Label Encoding***

# %%
print(f"Cardinality of 'city' : {df['city'].nunique()}")
# cardinality b/w 10 & 50 : we can choose Binary Encoding
# Out:
# Cardinality of 'city' : 26

# %%
binary_encoder = BinaryEncoder(cols="city")
encoded_df = binary_encoder.fit_transform(df)
encoded_df.head()
# Out:
#    city_0  city_1  city_2  city_3  city_4     pm2.5      pm10        no  \
# 0       0       0       0       0       1  4.400235  4.532815  0.883768
# 1       0       0       0       0       1  4.486387  4.532815  1.108563
# 2       0       0       0       0       1  4.516667  4.532815  1.000632
# 3       0       0       0       0       1  4.437107  4.532815  0.559616
# 4       0       0       0       0       1  4.239887  4.532815  0.457425
#
#         no2      n_ox  ...  benzene  toluene       aqi  day  month  year  \
# 0  3.131137  3.075005  ...      0.0      0.0  5.666427   29      1  2015
# 1  3.038313  3.145014  ...      0.0      0.0  5.204007   29      1  2015
# 2  3.049747  3.140698  ...      0.0      0.0  5.209486   29      1  2015
# 3  2.853593  2.861057  ...      0.0      0.0  5.209486   29      1  2015
# 4  2.689886  2.602690  ...      0.0      0.0  5.192957   29      1  2015
#
#    day_of_week  hour  is_weekend  season
# 0            3     9           0       0
# 1            3    10           0       0
# 2            3    11           0       0
# 3            3    12           0       0
# 4            3    13           0       0
#
# [5 rows x 24 columns]

# %%
encoded_df.columns
# Out:
# Index(['city_0', 'city_1', 'city_2', 'city_3', 'city_4', 'pm2.5', 'pm10', 'no',
#        'no2', 'n_ox', 'nh3', 'co', 'so2', 'o3', 'benzene', 'toluene', 'aqi',
#        'day', 'month', 'year', 'day_of_week', 'hour', 'is_weekend', 'season'],
#       dtype='object')

# %% [markdown]
# ### ***Standardization***

# %%
"""feature : target split"""

X = encoded_df.drop(["aqi"], axis=1)
Y = encoded_df["aqi"]

# %%
"""standardizing over min max scaling data bcz , all feature follow a normal distribution"""

standard_scaler = StandardScaler()
standardized_x = pd.DataFrame(standard_scaler.fit_transform(X), columns=X.columns)
standardized_x.head()
# Out:
#      city_0    city_1    city_2    city_3   city_4     pm2.5      pm10  \
# 0 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.644657  0.050355
# 1 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.746076  0.050355
# 2 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.781722  0.050355
# 3 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.688063  0.050355
# 4 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.455894  0.050355
#
#          no       no2      n_ox  ...        o3   benzene   toluene       day  \
# 0 -1.393542  0.086050  0.033354  ...  0.701922 -1.117163 -1.479028  1.501441
# 1 -1.170187 -0.022855  0.105121  ... -0.127273 -1.117163 -1.479028  1.501441
# 2 -1.277426 -0.009440  0.100697  ...  1.112832 -1.117163 -1.479028  1.501441
# 3 -1.715616 -0.239575 -0.185967  ...  1.417043 -1.117163 -1.479028  1.501441
# 4 -1.817152 -0.431640 -0.450823  ...  1.721293 -1.117163 -1.479028  1.501441
#
#       month      year  day_of_week      hour  is_weekend    season
# 0 -1.527203 -2.093452    -0.002554 -0.361599   -0.632988 -1.329244
# 1 -1.527203 -2.093452    -0.002554 -0.216941   -0.632988 -1.329244
# 2 -1.527203 -2.093452    -0.002554 -0.072283   -0.632988 -1.329244
# 3 -1.527203 -2.093452    -0.002554  0.072375   -0.632988 -1.329244
# 4 -1.527203 -2.093452    -0.002554  0.217033   -0.632988 -1.329244
#
# [5 rows x 23 columns]

# %%
"""concat the standardized feature + target variable"""

preprocessed_df = pd.concat([standardized_x, Y], axis=1)
preprocessed_df.head()
# Out:
#      city_0    city_1    city_2    city_3   city_4     pm2.5      pm10  \
# 0 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.644657  0.050355
# 1 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.746076  0.050355
# 2 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.781722  0.050355
# 3 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.688063  0.050355
# 4 -0.815813 -0.925448 -0.990663 -0.847216  0.76235  0.455894  0.050355
#
#          no       no2      n_ox  ...   benzene   toluene       day     month  \
# 0 -1.393542  0.086050  0.033354  ... -1.117163 -1.479028  1.501441 -1.527203
# 1 -1.170187 -0.022855  0.105121  ... -1.117163 -1.479028  1.501441 -1.527203
# 2 -1.277426 -0.009440  0.100697  ... -1.117163 -1.479028  1.501441 -1.527203
# 3 -1.715616 -0.239575 -0.185967  ... -1.117163 -1.479028  1.501441 -1.527203
# 4 -1.817152 -0.431640 -0.450823  ... -1.117163 -1.479028  1.501441 -1.527203
#
#        year  day_of_week      hour  is_weekend    season       aqi
# 0 -2.093452    -0.002554 -0.361599   -0.632988 -1.329244  5.666427
# 1 -2.093452    -0.002554 -0.216941   -0.632988 -1.329244  5.204007
# 2 -2.093452    -0.002554 -0.072283   -0.632988 -1.329244  5.209486
# 3 -2.093452    -0.002554  0.072375   -0.632988 -1.329244  5.209486
# 4 -2.093452    -0.002554  0.217033   -0.632988 -1.329244  5.192957
#
# [5 rows x 24 columns]

# %%
"""save label-encoder & standard-scaler for future prediction"""

if not os.path.exists("../model/encoders/"):
    os.mkdir("../model/encoders")
joblib.dump(binary_encoder, "../model/encoders/binary_encoder.joblib")
joblib.dump(standard_scaler, "../model/encoders/standard_scaler.joblib")
# Out:
# ['../model/encoders/standard_scaler.joblib']

# %%
"""save preprocessed dataset"""

if not os.path.exists("../data/preprocessed"):
    os.mkdir("../data/preprocessed")
    
preprocessed_df.to_csv("../data/preprocessed/preprocessed.csv", index=False)
print("cleaned dataset saved successfully")
# Out:
# cleaned dataset saved successfully

# %% [markdown]
# ### ***Next: Model Building***
